# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re

# %%
df = pd.read_csv('../sample_data/melbourne_house.csv', encoding='ISO-8859-1')
df
# Out:
#                  Suburb           Address  Rooms Type      Price Method  \
# 0            Abbotsford     49 Lithgow St      3    h  1490000.0      S
# 1            Abbotsford     59A Turner St      3    h  1220000.0      S
# 2            Abbotsford     119B Yarra St      3    h  1420000.0      S
# 3            Aberfeldie        68 Vida St      3    h  1515000.0      S
# 4          Airport West  92 Clydesdale Rd      2    h   670000.0      S
# ...                 ...               ...    ...  ...        ...    ...
# 63018     Roxburgh Park         3 Carr Pl      3    h   566000.0      S
# 63019     Roxburgh Park       9 Parker Ct      3    h   500000.0      S
# 63020     Roxburgh Park    5 Parkinson Wy      3    h   545000.0      S
# 63021        Thomastown    3/1 Travers St      3    u        NaN     PI
# 63022  Williams Landing       1 Diadem Wy      4    h        NaN     SP
#
#         SellerG        Date  Postcode             Regionname  Propertycount  \
# ...

# %%
filter1 = df.loc[(df['Rooms'] == 3) & (df['Type'] == 'h') & (df['Price'] <= 500000)]
filter1
# Out:
#                  Suburb          Address  Rooms Type     Price Method  \
# 92         Broadmeadows    145 Graham St      3    h  457000.0      S
# 170         Craigieburn     7A Amstel St      3    h  356500.0      S
# 177    Cranbourne North  22 Horsfield St      3    h  475000.0      S
# 183              Dallas    31 Phillip St      3    h  455500.0      S
# 192             Delahey    1/25 Yeats Dr      3    h  335000.0      S
# ...                 ...              ...    ...  ...       ...    ...
# 62977          Werribee      4 Mekong Cl      3    h  420000.0      S
# 62997      Wyndham Vale   5 Chatswood Pl      3    h  410000.0      S
# 62998      Wyndham Vale    21 Mermaid Cr      3    h  400000.0     SP
# 63000      Wyndham Vale       8 Opala Ct      3    h  416000.0      S
# 63019     Roxburgh Park      9 Parker Ct      3    h  500000.0      S
#
#              SellerG        Date  Postcode                  Regionname  \
# ...

# %%
filter2 = df.loc[df['Address'].str.contains('Turner St|Turner Rd', flags=re.I)]
filter2
# Out:
#              Suburb            Address  Rooms Type      Price Method  \
# 1        Abbotsford      59A Turner St      3    h  1220000.0      S
# 2859   Malvern East       24 Turner St      6    h  4700000.0      S
# 4723        Highett       48 Turner Rd      2    h   832000.0      S
# 4987     Abbotsford       85 Turner St      2    h  1480000.0      S
# 7501        Highett       28 Turner Rd      3    h        NaN     PI
# 9647     Abbotsford       53 Turner St      2    h        NaN      S
# 9648     Abbotsford       99 Turner St      2    h        NaN      S
# 14012       Berwick        4 Turner St      5    h   536000.0      S
# 14745   Westmeadows       16 Turner St      3    h        NaN     SN
# 18960  Moonee Ponds     3/16 Turner St      2    u   550000.0     VB
# 19148    Abbotsford  106/119 Turner St      1    u   481000.0     SP
# 19609       Highett     2/20 Turner Rd      2    u   730000.0     SP
# 20043   Westmeadows       14 Turner St      3    h   586000.0      S
# ...

# %%
filter3 = df.loc[df['Address'].str.contains('^59', flags=re.I) & (df['Price'] <= 500000)]
filter3
# Out:
#                  Suburb          Address  Rooms Type     Price Method  \
# 2220             Wallan    59 William St      3    h  424000.0      S
# 9096            Sunbury  59 Davenport Dr      3    h  499500.0      S
# 13089     Sunshine West   59 Felstead Av      3    h  465000.0      S
# 13840           Sunbury  59 Davenport Dr      3    h  499500.0      S
# 19616  Hoppers Crossing     59 Aitken Av      3    h  421600.0     SP
# 19623  Hoppers Crossing   59 Mossfiel Dr      3    h  453000.0      S
# 30441        Thomastown    59 Darebin Dr      3    h  478500.0      S
# 31889           Sunbury  59 Davenport Dr      3    h  499500.0      S
# 46682           Sunbury  59 Davenport Dr      3    h  499500.0      S
# 62903           Sunbury  59 Davenport Dr      3    h  499500.0      S
#
#              SellerG        Date  Postcode             Regionname  \
# 2220         Ruralco   2/06/2018      3756      Northern Victoria
# ...

# %%
# df.loc[df['SellerG'] == 'Nelson', 'SellerG'] = 'Ronald'
# df.loc[df['SellerG'] == 'Ronald', ['Method']] = 'P'

# %%
df.groupby(['SellerG']).sum().sort_values('Price', ascending=False).head(10)
# Out:
#                                                           Suburb  \
# SellerG
# Jellis         AbbotsfordAirport WestAlphingtonArmadaleArmada...
# Nelson         AbbotsfordAirport WestAirport WestBellfieldBru...
# Barry          AberfeldieAirport WestAltona MeadowsAttwoodBla...
# Marshall       AbbotsfordArmadaleBalwynBlack RockBrightonBrig...
# hockingstuart  AlbanvaleArmadaleArmadaleAspendaleAvondale Hei...
# Buxton         BeaumarisBeaumarisBentleighBentleigh EastBlack...
# Ray            Ascot ValeAshwoodAspendale GardensBeaumarisBru...
# Fletchers      AshburtonBalwynBalwyn NorthBalwyn NorthBalwyn ...
# Biggin         BoroniaBrunswick WestCaulfield SouthCraigiebur...
# Noel           BalwynBlackburnBlackburnBlackburn NorthBlackbu...
#
#                                                          Address  Rooms  \
# SellerG
# Jellis         49 Lithgow St4/32 Earl St41 Toolangi Rd2/23 As...  16948
# Nelson         119B Yarra St92 Clydesdale Rd1/26 Highridge Cr...  13808
# ...

# %%
df.groupby(['SellerG']).sum().sort_values('Rooms', ascending=False).head(10)
# Out:
#                                                           Suburb  \
# SellerG
# Barry          AberfeldieAirport WestAltona MeadowsAttwoodBla...
# Jellis         AbbotsfordAirport WestAlphingtonArmadaleArmada...
# Ray            Ascot ValeAshwoodAspendale GardensBeaumarisBru...
# Nelson         AbbotsfordAirport WestAirport WestBellfieldBru...
# hockingstuart  AlbanvaleArmadaleArmadaleAspendaleAvondale Hei...
# Buxton         BeaumarisBeaumarisBentleighBentleigh EastBlack...
# Marshall       AbbotsfordArmadaleBalwynBlack RockBrightonBrig...
# Fletchers      AshburtonBalwynBalwyn NorthBalwyn NorthBalwyn ...
# Biggin         BoroniaBrunswick WestCaulfield SouthCraigiebur...
# Harcourts      EppingGlen WaverleyGlen WaverleyGlen WaverleyM...
#
#                                                          Address  Rooms  \
# SellerG
# Barry          68 Vida St3/74 Hawker St57 Tatman Dr46 Threadn...  22919
# Jellis         49 Lithgow St4/32 Earl St41 Toolangi Rd2/23 As...  16948
# ...

# %%
plt.title('Preços de Casas por Número de Quartos em M US$')
plt.plot(df['Rooms'], df['Price'], 'r,--', label = 'Preço')
# plt.xticks(df['Rooms'][::5])

plt.xlabel('Rooms')
plt.ylabel('Price')

plt.legend()

# plt.savefig('Prices.jpg')
plt.show()
