# %%
import pandas as pd
import numpy as np
import sys

# %%
df = pd.read_csv('../sample_data/naruto.csv', encoding='ISO-8859-1')
df
# Out:
#      Unnamed: 0  Num_episode  \
# 0             1            1
# 1             2            2
# 2             3            3
# 3             4            4
# 4             5            5
# ..          ...          ...
# 495         496          496
# 496         497          497
# 497         498          498
# 498         499          499
# 499         500          500
#
#                                                  Title                Type  \
# 0                                           Homecoming  Mixed Canon/Filler
# 1                          The Akatsuki Makes Its Move  Mixed Canon/Filler
# 2                              The Results of Training  Mixed Canon/Filler
# 3                           The Jinchuriki of the Sand  Mixed Canon/Filler
# 4                             The Kazekage Stands Tall  Mixed Canon/Filler
# ..                                                 ...                 ...
# 495  Hidden Leaf Story, the Perfect Day for a Weddi...         Manga Canon
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0  Num_episode                                Title  \
# 0           1            1                           Homecoming
# 1           2            2          The Akatsuki Makes Its Move
# 2           3            3              The Results of Training
# 3           4            4           The Jinchuriki of the Sand
# 4           5            5             The Kazekage Stands Tall
# 5           6            6                      Mission Cleared
# 6           7            7                         Run, Kankuro
# 7           8            8               Team Kakashi, Deployed
# 8           9            9               The Jinchuriki's Tears
# 9          10           10  Sealing Jutsu: Nine Phantom Dragons
#
#                  Type  Year_launch  Rate  Votes                Saga  \
# 0  Mixed Canon/Filler         2007   8.2    728  s1 Kazekage Rescue
# 1  Mixed Canon/Filler         2007   8.0    575  s1 Kazekage Rescue
# ...

# %%
df.tail(10)
# Out:
#      Unnamed: 0  Num_episode  \
# 490         491          491
# 491         492          492
# 492         493          493
# 493         494          494
# 494         495          495
# 495         496          496
# 496         497          497
# 497         498          498
# 498         499          499
# 499         500          500
#
#                                                  Title         Type  \
# 490  Shikamarus Story, a Cloud Drifting in the Sil...  Manga Canon
# 491  Shikamarus Story, a Cloud Drifting in the Sil...  Manga Canon
# 492  Shikamarus Story, a Cloud Drifting in the Sil...  Manga Canon
# 493  Hidden Leaf Story, the Perfect Day for a Weddi...  Manga Canon
# 494  Hidden Leaf Story, the Perfect Day for a Weddi...  Manga Canon
# 495  Hidden Leaf Story, the Perfect Day for a Weddi...  Manga Canon
# 496  Hidden Leaf Story, the Perfect Day for a Weddi...  Manga Canon
# 497  Hidden Leaf Story, the Perfect Day for a Weddi...  Manga Canon
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Num_episode', 'Title', 'Type', 'Year_launch', 'Rate',
#        'Votes', 'Saga', 'Airdate'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=500, step=1)

# %%
df[['Title', 'Votes']]
# Out:
#                                                  Title  Votes
# 0                                           Homecoming    728
# 1                          The Akatsuki Makes Its Move    575
# 2                              The Results of Training    508
# 3                           The Jinchuriki of the Sand    517
# 4                             The Kazekage Stands Tall    486
# ..                                                 ...    ...
# 495  Hidden Leaf Story, the Perfect Day for a Weddi...    313
# 496  Hidden Leaf Story, the Perfect Day for a Weddi...    301
# 497  Hidden Leaf Story, the Perfect Day for a Weddi...    305
# 498  Hidden Leaf Story, the Perfect Day for a Weddi...    323
# 499  Hidden Leaf Story, the Perfect Day for a Weddi...   1288
#
# [500 rows x 2 columns]

# %%
df.iloc[1:6]
# Out:
#    Unnamed: 0  Num_episode                        Title                Type  \
# 1           2            2  The Akatsuki Makes Its Move  Mixed Canon/Filler
# 2           3            3      The Results of Training  Mixed Canon/Filler
# 3           4            4   The Jinchuriki of the Sand  Mixed Canon/Filler
# 4           5            5     The Kazekage Stands Tall  Mixed Canon/Filler
# 5           6            6              Mission Cleared  Mixed Canon/Filler
#
#    Year_launch  Rate  Votes                Saga     Airdate
# 1         2007   8.0    575  s1 Kazekage Rescue  2007-02-15
# 2         2007   8.0    508  s1 Kazekage Rescue  2007-02-22
# 3         2007   8.2    517  s1 Kazekage Rescue  2007-03-01
# 4         2007   8.2    486  s1 Kazekage Rescue  2007-03-15
# 5         2007   8.2    480  s1 Kazekage Rescue  2007-03-29

# %%
df.loc[df['Type'] == 'Filler']
# Out:
#      Unnamed: 0  Num_episode                 Title    Type  Year_launch  Rate  \
# 27           28           28  Beasts! Alive Again!  Filler         2007   7.1
# 56           57           57       Robbed of Sleep  Filler         2008   6.9
# 57           58           58            Loneliness  Filler         2008   6.6
# 58           59           59           A New Enemy  Filler         2008   6.5
# 59           60           60          Impermanence  Filler         2008   6.7
# ..          ...          ...                   ...     ...          ...   ...
# 467         468          468         The Successor  Filler         2016   8.2
# 479         480          480     Naruto and Hinata  Filler         2016   7.4
# 480         481          481     Sasuke and Sakura  Filler         2016   6.6
# 481         482          482   Gaara and Shikamaru  Filler         2016   6.7
# 482         483          483   Jiraiya and Kakashi  Filler         2016   6.8
#
# ...

# %%
df.sort_values('Title')
# Out:
#      Unnamed: 0  Num_episode                                      Title  \
# 461         462          462                          A Fabricated Past
# 296         297          297           A Father's Hope, a Mother's Love
# 383         384          384               A Heart Filled With Comrades
# 317         318          318  A Hole in the Heart: the Other Jinchuriki
# 12           13           13                     A Meeting With Destiny
# ..          ...          ...                                        ...
# 87           88           88                Wind Style: Rasen Shuriken!
# 345         346          346                            World of Dreams
# 471         472          472                              You Better...
# 416         417          417                        Youll Be My Backup
# 114         115          115                             Zabuza's Blade
#
#                    Type  Year_launch  Rate  Votes  \
# 461  Mixed Canon/Filler         2016   8.2    270
# ...

# %%
df.sort_values('Rate', ascending=False)
# Out:
#      Unnamed: 0  Num_episode                                       Title  \
# 476         477          477                           Naruto and Sasuke
# 132         133          133             The Tale of Jiraiya the Gallant
# 374         375          375                           Kakashi vs. Obito
# 475         476          476                            The Final Battle
# 248         249          249                                   Thank You
# ..          ...          ...                                         ...
# 433         434          434                                Team Jiraiya
# 448         449          449                           The Shinobi Unite
# 312         313          313  Rain Followed by Snow, with Some Lightning
# 375         376          376        The Directive to Take the Nine Tails
# 376         377          377                     Naruto vs. Mecha Naruto
#
#             Type  Year_launch  Rate  Votes  \
# 476  Manga Canon         2016   9.5   2780
# ...

# %%
df = df[['Title', 'Votes']]
df.sort_values('Votes', ascending=False)
# Out:
#                                Title  Votes
# 476                Naruto and Sasuke   2780
# 132  The Tale of Jiraiya the Gallant   2229
# 374                Kakashi vs. Obito   1732
# 321                    Madara Uchiha   1600
# 475                 The Final Battle   1596
# ..                               ...    ...
# 410        The Targeted Tailed Beast    164
# 434                Order of Priority    164
# 438            The Child of Prophecy    164
# 404              The Imprisoned Pair    163
# 408                      Their Backs    163
#
# [500 rows x 2 columns]

# %%
# df.to_csv('sample_data/naruto2.csv', index=False)

# %%
a = [1, 2, 3, 4, 5]
b = np.array([1, 2, 3, 4, 5])
a, b
# Out:
# ([1, 2, 3, 4, 5], array([1, 2, 3, 4, 5]))

# %%
sys.getsizeof(a), b.nbytes
# Out:
# (104, 20)

# %%
d1 = np.array([1, 2, 3])
d1, d1.shape, d1.ndim, d1.dtype
# Out:
# (array([1, 2, 3]), (3,), 1, dtype('int32'))

# %%
d2 = np.array([[1, 2, 3], [4, 5, 6]])
d2, d2.shape, d2.ndim, d2.dtype
# Out:
# (array([[1, 2, 3],
#         [4, 5, 6]]),
#  (2, 3),
#  2,
#  dtype('int32'))

# %%
d3 = np.array([[[1, 2], [3, 4]], [[5, 6], [7, 8]]])
d3, d3.shape, d3.ndim, d3.dtype
# Out:
# (array([[[1, 2],
#          [3, 4]],
#
#         [[5, 6],
#          [7, 8]]]),
#  (2, 2, 2),
#  3,
#  dtype('int32'))

# %%
d4 = np.array([2, 3, 4])
result = np.add(d1, d4)
result
# Out:
# array([3, 5, 7])

# %%
d2[1,1] #item
# Out:
# 5

# %%
d2[1,:] #linha
# Out:
# array([4, 5, 6])

# %%
d2[:, 2] #coluna
# Out:
# array([3, 6])
